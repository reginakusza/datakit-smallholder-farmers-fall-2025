# %% [markdown]
# # imports

# %%
import pandas as pd

# %%
wefarm = pd.read_csv(r"https://producersdirect-backups.s3.eu-west-1.amazonaws.com/athena-results/Unsaved/2025/09/26/b0cd514b-b9cc-4972-a0c2-c91726e6d825.csv")

# %% [markdown]
# # peek at the data

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 50)

wefarm.head(5)
# Out:
#    question_id  question_user_id question_language  \
# 0      3849056            519124               nyn
# 1      3849061            521327               eng
# 2      3849077            307821               nyn
# 3      3849077            307821               nyn
# 4      3849077            307821               nyn
#
#                                     question_content question_topic  \
# 0       E ABA WEFARM OFFICES ZABO NIZISHANGWA NKAHI?            NaN
# 1  Q this goes to wefarm. is it possible to get f...            NaN
# 2  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...         cattle
# 3  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...         cattle
# 4  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...            cat
#
#             question_sent  response_id  response_user_id response_language  \
# 0  2017-11-22 12:25:03+00     20691011            200868               nyn
# 1  2017-11-22 12:25:05+00      4334249            526113               eng
# 2  2017-11-22 12:25:08+00      3849291            296187               nyn
# 3  2017-11-22 12:25:08+00      3849291            296187               nyn
# 4  2017-11-22 12:25:08+00      3849291            296187               nyn
#
#                                     response_content response_topic  \
# 0                         E!23 Omubazi Ni Dudu Cipa'            NaN
# 1          Q1 which stage is marleks last vaccinated            NaN
# 2  Muhanguzi.Benon kuruga masha isingiro ente yaw...         tomato
# 3  Muhanguzi.Benon kuruga masha isingiro ente yaw...         cattle
# 4  Muhanguzi.Benon kuruga masha isingiro ente yaw...         tomato
#
#                    response_sent question_user_type question_user_status  \
# 0  2019-01-24 17:54:06.216221+00             farmer                 live
# 1         2018-01-04 08:57:28+00             farmer                 live
# 2         2017-11-22 12:35:26+00             farmer               zombie
# 3         2017-11-22 12:35:26+00             farmer               zombie
# 4         2017-11-22 12:35:26+00             farmer               zombie
#
#   question_user_country_code question_user_gender question_user_dob  \
# 0                         ug                  NaN               NaN
# 1                         ug                  NaN               NaN
# 2                         ug                  NaN               NaN
# 3                         ug                  NaN               NaN
# 4                         ug                  NaN               NaN
#
#   question_user_created_at response_user_type response_user_status  \
# 0   2017-11-18 13:09:11+00             farmer                 live
# 1   2017-11-20 11:55:48+00             farmer               zombie
# 2   2017-08-22 14:51:07+00             farmer               zombie
# 3   2017-08-22 14:51:07+00             farmer               zombie
# 4   2017-08-22 14:51:07+00             farmer               zombie
#
#   response_user_country_code response_user_gender response_user_dob  \
# 0                         ug                  NaN               NaN
# 1                         ug                  NaN               NaN
# 2                         ug                  NaN               NaN
# 3                         ug                  NaN               NaN
# 4                         ug                  NaN               NaN
#
#   response_user_created_at
# 0   2017-05-09 09:19:33+00
# 1   2017-11-22 10:13:03+00
# 2   2017-08-12 09:30:33+00
# 3   2017-08-12 09:30:33+00
# 4   2017-08-12 09:30:33+00

# %%
wefarm.shape
# Out:
# (20304843, 24)

# %% [markdown]
# # install libraries

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.1)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 80.4 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %% [markdown]
# # create dataframes by language

# %%
wefarm_eng_df = wefarm[wefarm["question_language"] == "eng"][["question_id", "question_content"]].drop_duplicates()

# %%
doc_lst = wefarm_eng_df["question_content"]

# %% [markdown]
# # install libraries

# %%
import nltk
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer
from gensim.utils import simple_preprocess
from tqdm import tqdm

# %% [markdown]
# #preprocessing

# %%
lem = WordNetLemmatizer()

def preprocess_text(text):
  tokens = simple_preprocess(text, deacc=True)
  return [lem.lemmatize(word, pos='v') for word in tokens]

# %%
processed_questions_eng_lst = []
for question in tqdm(doc_lst):
  processed_questions_eng_lst.append(preprocess_text(question))
# Out:
# 100%|██████████| 2940542/2940542 [01:55<00:00, 25484.47it/s]

# %% [markdown]
# # keyword extraction

# %%
# keywords manually extracted from previous LDA analysis

market_keywords_lst = [
  "price",
  "sell",
  "market",
  "buy",
  "cost",
  "fee"
]


crop_keywords_lst = [
  "soil",
  "fruit",
  "plant",
  "leave",
  "fertilizer",
  "seed",
  "potatoes",
  "passion",
  "maize",
  "tomatoes",
  "banana",
  "manure",
  "layer",
  "coffee",
  "onions",
  "grow",
  "mulch",
  "bean",
  "type",
  "cabbage",
  "land",
  "variety",
  "yield",
  "keep",
  "rice",
  "harvest",
]

seasonality_keywords_lst = [
  "season",
  "time",
]

disease_keywords_lst = [
  "disease",
  "medicine",
  "treat",
  "weed",
  "control",
  "plant",
  "leave",
  "spray",
  "harvest",
  "affect",
  "prevent",
  "pests",
  "chemical",
  "rabbit",
  "care",
  "tick",
  "attack",
  "mean",
  "black",
  "space",
  "turn",
  "keep"
]

livestock_keywords_lst = [
  "animals",
  "pig",
  "cow",
  "goat",
  "hen",
  "chicken",
  "poultry",
  "lay",
  "egg",
  "milk",
  "breed",
  "dairy",
]

# %%
# %%time

from gensim.models import Word2Vec
w2v_model = Word2Vec(processed_questions_eng_lst, min_count=1, vector_size=100)
# Out:
# CPU times: user 3min 14s, sys: 769 ms, total: 3min 14s
# Wall time: 1min 12s

# %%
def run_w2v_broad(keyword_lst, top_n=50):
  full_keyword_lst = []
  for word in keyword_lst:
    full_keyword_lst.extend([w for w, s in w2v_model.wv.most_similar(word, topn=top_n)])
  return full_keyword_lst

# %%
def run_w2v_niche(keyword_lst, top_n=50):
  niche_keyword_dct = {}
  for word in keyword_lst:
    niche_keyword_dct[word] =[w for w, s in w2v_model.wv.most_similar(word, topn=top_n)]
  return niche_keyword_dct

# %%
# %%time

market_keywords_full_lst = run_w2v_broad(market_keywords_lst)
crop_keywords_full_lst = run_w2v_broad(crop_keywords_lst)
seasonality_keywords_full_lst = run_w2v_broad(seasonality_keywords_lst)
disease_keywords_full_lst = run_w2v_broad(disease_keywords_lst)
livestock_keywords_full_lst = run_w2v_broad(livestock_keywords_lst)
# Out:
# CPU times: user 3.64 s, sys: 2.97 ms, total: 3.64 s
# Wall time: 155 ms

# %%
# %%time

market_keywords_niche_dct = run_w2v_niche(market_keywords_lst)
crop_keywords_niche_dct = run_w2v_niche(crop_keywords_lst)
seasonality_keywords_niche_dct = run_w2v_niche(seasonality_keywords_lst)
disease_keywords_niche_dct = run_w2v_niche(disease_keywords_lst)
livestock_keywords_niche_dct = run_w2v_niche(livestock_keywords_lst)
# Out:
# CPU times: user 3.55 s, sys: 967 µs, total: 3.56 s
# Wall time: 149 ms

# %%
niche_category_dct = {
  "market": market_keywords_niche_dct,
  "crop": crop_keywords_niche_dct,
  "seasonality": seasonality_keywords_niche_dct,
  "disease": disease_keywords_niche_dct,
  "livestock": livestock_keywords_niche_dct
}

# %%
broad_category_dct = {
    "market": market_keywords_full_lst,
    "crop": crop_keywords_full_lst,
    "seasonality": seasonality_keywords_full_lst,
    "disease": disease_keywords_full_lst,
    "livestock": livestock_keywords_full_lst
}

# %% [markdown]
# # keyword categorization

# %% [markdown]
# ## niche keywords

# %%
def find_niche_keywords(doc):
  doc_words = set(doc)
  matches_dct = {}
  for category, sub_dct in niche_category_dct.items():
    for sub_category, keywords in sub_dct.items():
      if any(keyword in doc_words for keyword in keywords):
        matches_dct[f"{category}_{sub_category}"] = 1
  return matches_dct

# %%
niche_res_lst = []

for doc in tqdm(processed_questions_eng_lst):
  matches_dct = find_niche_keywords(doc)
  niche_res_lst.append(matches_dct)
# Out:
# 100%|██████████| 2940542/2940542 [07:32<00:00, 6498.26it/s]

# %%
# %%time

niche_res_df = pd.DataFrame(niche_res_lst)
# Out:
# CPU times: user 13.2 s, sys: 731 ms, total: 13.9 s
# Wall time: 13.9 s

# %%
joined_niche_questions_eng_lst = [" ".join(doc) for doc in processed_questions_eng_lst]
niche_questions_eng_df = pd.DataFrame({
  "preprocessed_question": joined_niche_questions_eng_lst
})

# %%
niche_questions_id_eng_df = pd.concat([niche_questions_eng_df.reset_index(drop=True), wefarm_eng_df.reset_index(drop=True)], axis=1)
niche_questions_categories_df = pd.concat([niche_questions_id_eng_df, niche_res_df], axis=1)

# %%
niche_questions_categories_df.head(5)
# Out:
#                                preprocessed_question  question_id  \
# 0  this go to wefarm be it possible to get for us...      3849061
# 1  have stock rabbit urine for weeks mashambani s...      3849084
# 2  have mi can start aproject of poutry how can d...      3849098
# 3                       where do get seed of coconut      3849100
# 4                             which plant have omega      3849129
#
#                                     question_content  market_price  \
# 0  Q this goes to wefarm. is it possible to get f...           1.0
# 1  Q-i have stock rabbit's urine for 5 weeks mash...           NaN
# 2  Q J Have Mi 10000 Can J Start Aproject Of Pout...           NaN
# 3                   WHERE DO I GET SEEDS OF COCONUT?           NaN
# 4                         Q#.Which plant has omega3?           NaN
#
#    market_sell  market_buy  crop_yield  seasonality_time  livestock_animals  \
# 0          1.0         1.0         1.0               NaN                NaN
# 1          1.0         NaN         NaN               1.0                1.0
# 2          NaN         NaN         NaN               NaN                NaN
# 3          1.0         1.0         NaN               NaN                NaN
# 4          NaN         NaN         NaN               NaN                NaN
#
#    livestock_pig  livestock_cow  livestock_goat  livestock_hen  \
# 0            NaN            NaN             NaN            NaN
# 1            1.0            1.0             1.0            1.0
# 2            NaN            NaN             NaN            1.0
# 3            NaN            NaN             NaN            NaN
# 4            NaN            NaN             NaN            NaN
#
#    livestock_chicken  crop_layer  livestock_poultry  crop_plant  crop_variety  \
# 0                NaN         NaN                NaN         NaN           NaN
# 1                1.0         NaN                NaN         NaN           NaN
# 2                1.0         1.0                1.0         NaN           NaN
# 3                NaN         NaN                NaN         1.0           1.0
# 4                NaN         NaN                NaN         NaN           NaN
#
#    crop_harvest  disease_plant  disease_harvest  crop_seed  crop_grow  \
# 0           NaN            NaN              NaN        NaN        NaN
# 1           NaN            NaN              NaN        NaN        NaN
# 2           NaN            NaN              NaN        NaN        NaN
# 3           1.0            1.0              1.0        NaN        NaN
# 4           1.0            NaN              1.0        1.0        1.0
#
#    crop_mulch  crop_potatoes  crop_passion  crop_maize  crop_banana  \
# 0         NaN            NaN           NaN         NaN          NaN
# 1         NaN            NaN           NaN         NaN          NaN
# 2         NaN            NaN           NaN         NaN          NaN
# 3         NaN            NaN           NaN         NaN          NaN
# 4         1.0            NaN           NaN         NaN          NaN
#
#    crop_coffee  crop_onions  crop_cabbage  disease_rabbit  crop_tomatoes  \
# 0          NaN          NaN           NaN             NaN            NaN
# 1          NaN          NaN           NaN             NaN            NaN
# 2          NaN          NaN           NaN             NaN            NaN
# 3          NaN          NaN           NaN             NaN            NaN
# 4          NaN          NaN           NaN             NaN            NaN
#
#    crop_bean  crop_rice  disease_disease  disease_care  crop_keep  \
# 0        NaN        NaN              NaN           NaN        NaN
# 1        NaN        NaN              NaN           NaN        NaN
# 2        NaN        NaN              NaN           NaN        NaN
# 3        NaN        NaN              NaN           NaN        NaN
# 4        NaN        NaN              NaN           NaN        NaN
#
#    disease_keep  market_market  market_cost  livestock_egg  disease_treat  \
# 0           NaN            NaN          NaN            NaN            NaN
# 1           NaN            NaN          NaN            NaN            NaN
# 2           NaN            NaN          NaN            NaN            NaN
# 3           NaN            NaN          NaN            NaN            NaN
# 4           NaN            NaN          NaN            NaN            NaN
#
#    disease_prevent  disease_chemical  crop_fruit  livestock_milk  crop_land  \
# 0              NaN               NaN         NaN             NaN        NaN
# 1              NaN               NaN         NaN             NaN        NaN
# 2              NaN               NaN         NaN             NaN        NaN
# 3              NaN               NaN         NaN             NaN        NaN
# 4              NaN               NaN         NaN             NaN        NaN
#
#    livestock_breed  crop_manure  seasonality_season  disease_control  \
# 0              NaN          NaN                 NaN              NaN
# 1              NaN          NaN                 NaN              NaN
# 2              NaN          NaN                 NaN              NaN
# 3              NaN          NaN                 NaN              NaN
# 4              NaN          NaN                 NaN              NaN
#
#    livestock_dairy  crop_soil  disease_spray  disease_turn  disease_attack  \
# 0              NaN        NaN            NaN           NaN             NaN
# 1              NaN        NaN            NaN           NaN             NaN
# 2              NaN        NaN            NaN           NaN             NaN
# 3              NaN        NaN            NaN           NaN             NaN
# 4              NaN        NaN            NaN           NaN             NaN
#
#    crop_type  crop_leave  disease_medicine  disease_leave  disease_tick  \
# 0        NaN         NaN               NaN            NaN           NaN
# 1        NaN         NaN               NaN            NaN           NaN
# 2        NaN         NaN               NaN            NaN           NaN
# 3        NaN         NaN               NaN            NaN           NaN
# 4        NaN         NaN               NaN            NaN           NaN
#
#    disease_weed  disease_pests  livestock_lay  market_fee  disease_black  \
# 0           NaN            NaN            NaN         NaN            NaN
# 1           NaN            NaN            NaN         NaN            NaN
# 2           NaN            NaN            NaN         NaN            NaN
# 3           NaN            NaN            NaN         NaN            NaN
# 4           NaN            NaN            NaN         NaN            NaN
#
#    disease_space  crop_fertilizer  disease_affect  disease_mean
# 0            NaN              NaN             NaN           NaN
# 1            NaN              NaN             NaN           NaN
# 2            NaN              NaN             NaN           NaN
# 3            NaN              NaN             NaN           NaN
# 4            NaN              NaN             NaN           NaN

# %%
keyword_collst = niche_questions_categories_df.columns[3:]
keyword_sums = niche_questions_categories_df[keyword_collst].sum().sort_values()
sums_df = keyword_sums.reset_index()
sums_df.columns = ["col", "sum"]

sums_df["prefix"] = [c.split("_")[0] for c in sums_df["col"]]

sums_df = sums_df.sort_values(["prefix", "sum"], ascending=[True, False])

keyword_sums_dct = dict(zip(sums_df["col"], sums_df["sum"]))

# %%
import plotly.graph_objects as go

fig = go.Figure()

for k, v in keyword_sums_dct.items():
  fig.add_trace(
    go.Bar(
      x=[k],
      y=[v],
      marker={
        "color": [v],
        "colorscale": "greens"
      },
      name=k,
    )
  )

fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e86c2f78-483d-4e56-bab2-979e8efa493f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e86c2f78-483d-4e56-bab2-979e8efa493f")) {                    Plotly.newPlot(                        "e86c2f78-483d-4e56-bab2-979e8efa493f",                        [{"marker":{"color":[664727.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_coffee","x":["crop_coffee"],"y":[664727.0],"type":"bar"},{"marker":{"color":[652061.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_bean","x":["crop_bean"],"y":[652061.0],"type":"bar"},{"marker":{"color":[608338.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_maize","x":["crop_maize"],"y":[608338.0],"type":"bar"},{"marker":{"color":[587393.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_tomatoes","x":["crop_tomatoes"],"y":[587393.0],"type":"bar"},{"marker":{"color":[584486.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_potatoes","x":["crop_potatoes"],"y":[584486.0],"type":"bar"},{"marker":{"color":[581148.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_harvest","x":["crop_harvest"],"y":[581148.0],"type":"bar"},{"marker":{"color":[573321.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_banana","x":["crop_banana"],"y":[573321.0],"type":"bar"},{"marker":{"color":[469716.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_seed","x":["crop_seed"],"y":[469716.0],"type":"bar"},{"marker":{"color":[467140.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_rice","x":["crop_rice"],"y":[467140.0],"type":"bar"},{"marker":{"color":[453829.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_mulch","x":["crop_mulch"],"y":[453829.0],"type":"bar"},{"marker":{"color":[437422.0],"colorscale" ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
niche_questions_categories_df.to_parquet("en_questions_cat_niche.parquet", index=False)
# !cp en_questions_cat_niche.parquet /content/drive/MyDrive/DataKit_WeFarm

# %% [markdown]
# ## broad keywords

# %%
def find_keywords(doc):
  doc_words = set(doc)
  matches_dct = {}
  for category, keywords in broad_category_dct.items():
    if any(keyword in doc_words for keyword in keywords):
      matches_dct[category] = 1
  return matches_dct

# %%
broad_res_lst = []

for doc in tqdm(processed_questions_eng_lst):
  matches_dct = find_keywords(doc)
  broad_res_lst.append(matches_dct)
# Out:
# 100%|██████████| 2940542/2940542 [04:01<00:00, 12166.68it/s]

# %%
broad_res_df = pd.DataFrame(broad_res_lst)

# %%
broad_joined_questions_eng_lst = [" ".join(doc) for doc in processed_questions_eng_lst]
broad_questions_eng_df = pd.DataFrame({
  "preprocessed_question": broad_joined_questions_eng_lst
})

# %%
broad_questions_id_eng_df = pd.concat([broad_questions_eng_df.reset_index(drop=True), wefarm_eng_df.reset_index(drop=True)], axis=1)
broad_questions_categories_df = pd.concat([broad_questions_id_eng_df, broad_res_df], axis=1)

# %%
broad_questions_categories_df.head(5)
# Out:
#                                preprocessed_question  question_id  \
# 0  this go to wefarm be it possible to get for us...      3849061
# 1  have stock rabbit urine for weeks mashambani s...      3849084
# 2  have mi can start aproject of poutry how can d...      3849098
# 3                       where do get seed of coconut      3849100
# 4                             which plant have omega      3849129
#
#                                     question_content  market  crop  \
# 0  Q this goes to wefarm. is it possible to get f...     1.0   1.0
# 1  Q-i have stock rabbit's urine for 5 weeks mash...     1.0   NaN
# 2  Q J Have Mi 10000 Can J Start Aproject Of Pout...     NaN   1.0
# 3                   WHERE DO I GET SEEDS OF COCONUT?     1.0   1.0
# 4                         Q#.Which plant has omega3?     NaN   1.0
#
#    seasonality  livestock  disease
# 0          NaN        NaN      NaN
# 1          1.0        1.0      NaN
# 2          NaN        1.0      NaN
# 3          NaN        NaN      1.0
# 4          NaN        NaN      1.0

# %%
broad_questions_categories_df.to_parquet("en_questions_cat_broad.parquet", index=False)
# !cp en_questions_cat_broad.parquet /content/drive/MyDrive/DataKit_WeFarm

# %%
broad_questions_categories_df[["market", "disease", "crop", "seasonality", "livestock"]].isnull().all(axis=1).sum()
# Out:
# np.int64(258333)

# %%
sum_market = broad_questions_categories_df["market"].sum()
sum_livestock = broad_questions_categories_df["livestock"].sum()
sum_crop = broad_questions_categories_df["crop"].sum()
sum_disease = broad_questions_categories_df["disease"].sum()
sum_seasonality = broad_questions_categories_df["seasonality"].sum()

# %%
count_dct = {
  "market": sum_market,
  "livestock": sum_livestock,
  "crop": sum_crop,
  "disease": sum_disease,
  "seasonality": sum_seasonality,
  "nan": broad_questions_categories_df[["market", "disease", "crop", "seasonality", "livestock"]].isnull().all(axis=1).sum()
}

# %%
import plotly.graph_objects as go

fig = go.Figure()

for k, v in count_dct.items():
  fig.add_trace(
    go.Bar(
      x=[k],
      y=[v],
      marker={
        "color": [v],
        "colorscale": "greens"
      },
      name=k,
    )
  )

# %%
fig.update_layout({
  "title": "Reduced nulls from 1.6 million to 0.4 million"
})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5e97cd63-b8cd-42ed-b4e4-2944dfadca07" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e97cd63-b8cd-42ed-b4e4-2944dfadca07")) {                    Plotly.newPlot(                        "5e97cd63-b8cd-42ed-b4e4-2944dfadca07",                        [{"marker":{"color":[746503.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"market","x":["market"],"y":[746503.0],"type":"bar"},{"marker":{"color":[1056479.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"livestock","x":["livestock"],"y":[1056479.0],"type":"bar"},{"marker":{"color":[2015935.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop","x":["crop"],"y":[2015935.0],"type":"bar"},{"marker":{"color":[1793297.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"disease","x":["disease"],"y":[1793297.0],"type":"bar"},{"marker":{"color":[324150.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"seasonality","x":["seasonality"],"y":[324150.0],"type":"bar"},{"marker":{"color":[258333],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"nan","x":["nan"],"y":[258333],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c1 ...

# %%
from plotly.subplots import make_subplots

bigfig = make_subplots(
  1, 6,
  specs=[[{'type': 'pie'}] * 6]
  )

for idx, (k, v) in enumerate(count_dct.items()):
  bigfig.add_trace(
    go.Pie(
      labels=[k, "not"],
      values=[v, len(broad_questions_categories_df) - v],
      marker={"colors": ["#D742A8", "#E7E7E7"]}
    ),
    row=1, col=idx+1
  )

bigfig.update_layout({
  "title": 'The majority of all questions concern "crops" and/or "disease"'
})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cc161ffa-64ea-4a8f-a305-5ded8ae50de5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc161ffa-64ea-4a8f-a305-5ded8ae50de5")) {                    Plotly.newPlot(                        "cc161ffa-64ea-4a8f-a305-5ded8ae50de5",                        [{"labels":["market","not"],"marker":{"colors":["#D742A8","#E7E7E7"]},"values":[746503.0,2194039.0],"type":"pie","domain":{"x":[0.0,0.1388888888888889],"y":[0.0,1.0]}},{"labels":["livestock","not"],"marker":{"colors":["#D742A8","#E7E7E7"]},"values":[1056479.0,1884063.0],"type":"pie","domain":{"x":[0.17222222222222222,0.3111111111111111],"y":[0.0,1.0]}},{"labels":["crop","not"],"marker":{"colors":["#D742A8","#E7E7E7"]},"values":[2015935.0,924607.0],"type":"pie","domain":{"x":[0.34444444444444444,0.48333333333333334],"y":[0.0,1.0]}},{"labels":["disease","not"],"marker":{"colors":["#D742A8","#E7E7E7"]},"values":[1793297.0,1147245.0],"type":"pie","domain":{"x":[0.5166666666666667,0.6555555555555557],"y":[0.0,1.0]}},{"labels":["seasonality","not"],"marker":{"colors":["#D742A8","#E7E7E7"]},"values":[324150.0,2616392.0],"type":"pie","domain":{"x":[0.6888888888888889,0.8277777777777777],"y":[0.0,1.0]}},{"labels":["nan","not"],"marker":{"colors":["#D742A8","#E7E7E7"]},"values":[258333,2682209],"type":"pie","domain":{"x":[0.861111111111111,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777 ...

# %%
broad_questions_categories_df.to_parquet("en_questions_cat_broad.parquet", index=False)
# !cp en_questions_cat_broad.parquet /content/drive/MyDrive/DataKit_WeFarm

# %%
broad_questions_categories_df[["market", "disease", "crop", "seasonality", "livestock"]].isnull().all(axis=1).sum()
# Out:
# np.int64(379766)
