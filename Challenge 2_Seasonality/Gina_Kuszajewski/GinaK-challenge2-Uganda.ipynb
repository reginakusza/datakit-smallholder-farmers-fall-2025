# %%
# This is a temp file to show Gina how Git works

# %%
import pandas as pd
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
import re

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import gensim
from gensim import corpora, models

from tensorflow import keras
from tensorflow.keras import layers
# Out:
# 2025-11-20 14:50:17.523602: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
df = pd.read_parquet('datakit_farmers.parquet')

# %%
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk import pos_tag
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('words')
import regex as re
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/reginakuszsajewski/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/reginakuszsajewski/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/reginakuszsajewski/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/reginakuszsajewski/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/reginakuszsajewski/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
def preprocessing_steps(text):
    standard_txt = text.lower()
    # remove multiple white spaces and line breaks
    clean_txt = re.sub(r'\n', ' ', standard_txt)
    clean_txt = re.sub(r'\s+', ' ', clean_txt)
    clean_txt = clean_txt.strip()
    extra_stop_words = ['q', 'e', 'j', 'go', 'get']
    nan = 'nan'
    # tokenize text
    tokens = nltk.word_tokenize(clean_txt)
    # remove non-alphabetic tokens
    filtered_tokens_alpha = [word for word in tokens if word.isalpha() and not re.match(r'^[ivxlcdm]+$', word.lower())]
    #remove stop words
    stop_words = nltk.corpus.stopwords.words('english')
    no_null_text = [word for word in filtered_tokens_alpha if word != nan]
    return no_null_text

# %%
df.head()
# Out:
#    question_id  question_user_id question_language  \
# 0      3849056            519124               nyn
# 1      3849061            521327               eng
# 2      3849077            307821               nyn
# 3      3849077            307821               nyn
# 4      3849077            307821               nyn
#
#                                     question_content question_topic  \
# 0       E ABA WEFARM OFFICES ZABO NIZISHANGWA NKAHI?           None
# 1  Q this goes to wefarm. is it possible to get f...           None
# 2  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...         cattle
# 3  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...         cattle
# 4  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...            cat
#
#             question_sent  response_id  response_user_id response_language  \
# 0  2017-11-22 12:25:03+00     20691011            200868               nyn
# 1  2017-11-22 12:25:05+00      4334249            526113               eng
# 2  2017-11-22 12:25:08+00      3849291            296187               nyn
# 3  2017-11-22 12:25:08+00      3849291            296187               nyn
# 4  2017-11-22 12:25:08+00      3849291            296187               nyn
#
#                                     response_content  ...  \
# 0                         E!23 Omubazi Ni Dudu Cipa'  ...
# 1          Q1 which stage is marleks last vaccinated  ...
# 2  Muhanguzi.Benon kuruga masha isingiro ente yaw...  ...
# 3  Muhanguzi.Benon kuruga masha isingiro ente yaw...  ...
# 4  Muhanguzi.Benon kuruga masha isingiro ente yaw...  ...
#
#   question_user_country_code question_user_gender question_user_dob  \
# 0                         ug                 None              None
# 1                         ug                 None              None
# 2                         ug                 None              None
# 3                         ug                 None              None
# 4                         ug                 None              None
#
#   question_user_created_at response_user_type response_user_status  \
# 0   2017-11-18 13:09:11+00             farmer                 live
# 1   2017-11-20 11:55:48+00             farmer               zombie
# 2   2017-08-22 14:51:07+00             farmer               zombie
# 3   2017-08-22 14:51:07+00             farmer               zombie
# 4   2017-08-22 14:51:07+00             farmer               zombie
#
#   response_user_country_code response_user_gender response_user_dob  \
# 0                         ug                 None              None
# 1                         ug                 None              None
# 2                         ug                 None              None
# 3                         ug                 None              None
# 4                         ug                 None              None
#
#   response_user_created_at
# 0   2017-05-09 09:19:33+00
# 1   2017-11-22 10:13:03+00
# 2   2017-08-12 09:30:33+00
# 3   2017-08-12 09:30:33+00
# 4   2017-08-12 09:30:33+00
#
# [5 rows x 24 columns]

# %%
columns_wanted = ['question_content', 'question_user_country_code', 'question_sent', 'question_topic', 'question_language']
ug_df = df[columns_wanted]
ug_df = ug_df[ug_df['question_user_country_code'] == 'ug'] #I want to focus just on Ugandan farmers
ug_df = ug_df.drop_duplicates().dropna()

# %%
ug_df = ug_df.drop_duplicates(subset = 'question_content') #dropping more duplicates because some are spam that mess everything up

# %%
ug_df['question_language'].value_counts()
# Out:
# question_language
# eng    851256
# nyn    222717
# lug    145583
# Name: count, dtype: int64

# %%
eng_qs = ug_df[ug_df['question_language'] == 'eng']

# %%
eng_qs['cleaned_tokens'] = eng_qs['question_content'].apply(preprocessing_steps)
# Out:
# /var/folders/zn/cnbb8tdj24g_h7k2_x0gxqwc0000gn/T/ipykernel_69691/2207276115.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eng_qs['cleaned_tokens'] = eng_qs['question_content'].apply(preprocessing_steps)

# %%
print(eng_qs[['cleaned_tokens', 'question_content']].head())
# Out:
#                                        cleaned_tokens  \
# 15  [q, j, have, can, j, start, aproject, of, pout...
# 26  [q, am, jackson, from, ibanda, if, want, to, g...
# 39     [how, can, manage, my, coffee, from, diseases]
# 43  [how, can, raise, coffee, plants, from, seedling]
# 64  [which, medicine, can, be, given, to, pigs, wi...
#
#                                      question_content
# 15  Q J Have Mi 10000 Can J Start Aproject Of Pout...
# 26  Q Am Jackson From Ibanda If Want To Grow Tomat...
# 39           how can i manage my coffee from diseases
# 43       how can i raise coffee plants from seedling?
# 64  WHICH MEDICINE CAN BE GIVEN TO PIGS WITH SWINE...

# %%
topics_keywords = {
    "Planting / Crops": ["seed", "seeds", "sow", "germinate", "plant", "crop", "variety", "spacing", "soil preparation", "planting"],
    "Harvest / Post-Harvest": ["harvest", "yield", "pick", "collect", "storage", "preservation", "drying", "transport", "milling"],
    "Pests / Diseases / Soil": ["pest", "disease", "insect", "fungus", "soil", "nutrient", "fertilizer", "organic", "compost", "infection"],
    "Irrigation / Water": ["water", "irrigation", "drip", "sprinkler", "rainfall", "drought", "moisture", "flood"],
    "Livestock / Animal Husbandry": ["feed", "nutrition", "breeding", "vaccination", "health", "housing", "cow", "chicken", "animal"],
    "Markets / Economics": ["market", "price", "demand", "sell", "buy", "profit", "export", "income", "cooperative"],
    "Technology / Equipment": ["tractor", "harvester", "machine", "tool", "app", "sensor", "automation", "equipment"],
    "Policy / Finance": ["subsidy", "loan", "insurance", "government", "certification", "organic", "policy", "regulation"]
}

# %%
def assign_topics(question):
    question_lower = question.lower()
    matched_topics = []
    for topic, keywords in topics_keywords.items():
        for kw in keywords:
            # Use word boundaries to avoid partial matches
            if re.search(r'\b' + re.escape(kw) + r'\b', question_lower):
                matched_topics.append(topic)
                break  # stop after first keyword match per topic
    if not matched_topics:
        matched_topics = ["Misc / Other"]
    return "; ".join(matched_topics)

# %%
eng_qs['question_type'] = eng_qs['cleaned_tokens'].astype(str).apply(assign_topics)
# Out:
# /var/folders/zn/cnbb8tdj24g_h7k2_x0gxqwc0000gn/T/ipykernel_69691/1146577185.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eng_qs['question_type'] = eng_qs['cleaned_tokens'].astype(str).apply(assign_topics)

# %%
eng_qs['question_type'].value_counts()
# Out:
# question_type
# Misc / Other                                                                                                         548260
# Planting / Crops                                                                                                     115547
# Markets / Economics                                                                                                   56737
# Livestock / Animal Husbandry                                                                                          49178
# Pests / Diseases / Soil                                                                                               35012
#                                                                                                                       ...
# Irrigation / Water; Markets / Economics; Technology / Equipment                                                           1
# Technology / Equipment; Policy / Finance                                                                                  1
# Planting / Crops; Harvest / Post-Harvest; Pests / Diseases / Soil; Livestock / Animal Husbandry; Policy / Finance         1
# Planting / Crops; Pests / Diseases / Soil; Irrigation / Water; Markets / Economics; Policy / Finance                      1
# Livestock / Animal Husbandry; Markets / Economics; Policy / Finance                                                       1
# Name: count, Length: 87, dtype: int64

# %%
topic_counts = (
    eng_qs.groupby(['question_type'])
      .size()
      .reset_index(name='count')
)

top10 = (
    topic_counts
    .sort_values(['count'], ascending=False)
    .head(10)
)

# %%
top10
# Out:
#                                 question_type   count
# 23               Livestock / Animal Husbandry  402400
# 49                           Planting / Crops  196758
# 34                    Pests / Diseases / Soil  128915
# 30                        Markets / Economics   56737
# 33                               Misc / Other   17283
# 0                      Harvest / Post-Harvest   13113
# 16                         Irrigation / Water    8575
# 71  Planting / Crops; Pests / Diseases / Soil    5549
# 68      Planting / Crops; Markets / Economics    3631
# 61       Planting / Crops; Irrigation / Water    2851

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))

sns.barplot(
    data=top10,
    x='question_type',
    y='count',
    hue = 'question_type',
    palette='gist_earth')

plt.xticks(rotation=45, ha='right')
plt.ylabel("Number of Questions")
plt.xlabel("Question Type")
plt.title("Distribution of Assigned Question Types")

# Optional: add counts on top of bars
for p in plt.gca().patches:
    height = p.get_height()
    plt.gca().annotate(
        f'{int(height)}',
        (p.get_x() + p.get_width()/2., height + 0.5),  # adjust offset
        ha='center',
        va='bottom'
    )
plt.savefig('plot4.png')
plt.show()
# Out:
# /var/folders/zn/cnbb8tdj24g_h7k2_x0gxqwc0000gn/T/ipykernel_69691/3545185517.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
misc_df = eng_qs[eng_qs['question_type'] == 'Misc / Other']
misc_texts = misc_df['cleaned_tokens'].tolist()
misc_df['cleaned_text'] = misc_df['cleaned_tokens'].apply(lambda toks: " ".join(toks))
misc_texts = misc_df['cleaned_text'].tolist()
# Out:
# /var/folders/zn/cnbb8tdj24g_h7k2_x0gxqwc0000gn/T/ipykernel_69691/3860226040.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   misc_df['cleaned_text'] = misc_df['cleaned_tokens'].apply(lambda toks: " ".join(toks))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(
    min_df=5,
    max_df=0.6,
    ngram_range=(1,2),
    stop_words='english'
)

X = tfidf.fit_transform(misc_texts)

# %%
from sklearn.cluster import MiniBatchKMeans

k = 10
kmeans = MiniBatchKMeans(n_clusters=k, batch_size=2048, random_state=42)
labels = kmeans.fit_predict(X)
# Out:
# Python(70273) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.

# %%
import numpy as np

terms = tfidf.get_feature_names_out()

for i in range(k):
    print(f"\nCluster {i} top terms:")
    center = kmeans.cluster_centers_[i]
    top_idx = center.argsort()[-15:][::-1]
    print([terms[i] for i in top_idx])
# Out:
# Cluster 0 top terms:
# ['spray', 'use spray', 'use', 'spray tomatoes', 'used spray', 'chemical', 'tomatoes', 'used', 'spray maize', 'spray beans', 'medicine', 'chemical use', 'maize', 'beans', 'chemicals']
#
# Cluster 1 top terms:
# ['causes', 'tomato', 'leaves', 'animals', 'wat causes', 'tomato garden', 'garden', 'cattle', 'type tomato', 'bright', 'wat', 'tomatoes', 'blight', 'plants', 'tomato bright']
#
# Cluster 2 top terms:
# ['maize', 'kg', 'kg maize', 'type maize', 'grow', 'type', 'maize garden', 'best', 'grow maize', 'garden', 'cost', 'control', 'cost maize', 'hw', 'maize grow']
#
# Cluster 3 top terms:
# ['grow', 'beans', 'type', 'grow tomatoes', 'tomatoes', 'want', 'long', 'best', 'want grow', 'faster', 'does', 'grow faster', 'pigs grow', 'hw', 'kg']
#
# Cluster 4 top terms:
# ['response', 'followed', 'followed response', 'reply followed', 'reply', 'asks', 'optout', 'optout stop', 'response optout', 'stop', 'farmer asks', 'farmer', 'type', 'use', 'best']
#
# Cluster 5 top terms:
# ['crops', 'grow', 'crops grow', 'crops grown', 'grown', 'season', 'grow crops', 'cash', 'cash crops', 'pests', 'crops like', 'type crops', 'growing', 'growing crops', 'like']
#
# Cluster 6 top terms:
# ['banana', 'banana plantation', 'plantation', 'wilt', 'banana wilt', 'bacteria', 'control banana', 'control', 'banana bacteria', 'bacteria wilt', 'banana plants', 'prevent banana', 'prevent', 'plants', 'bacterial']
#
# Cluster 7 top terms:
# ['tomatoes', 'pigs', 'pig', 'best', 'coffee', 'does', 'hens', 'long', 'animals', 'cattle', 'type', 'good', 'hw', 'hen', 'goat']
#
# Cluster 8 top terms:
# ['use', 'cassava', 'medicine use', 'medicine', 'chemical use', 'chemical', 'tomatoes', 'control', 'use control', 'use treat', 'type', 'mosaic', 'cassava mosaic', 'garden', 'treat']
#
# Cluster 9 top terms:
# ['poultry', 'poultry farm', 'start poultry', 'farm', 'start', 'poultry keeping', 'keeping', 'vices', 'poultry house', 'house', 'poultry birds', 'birds', 'poultry vices', 'diseases', 'causes']

# %%
misc_df['misc_cluster'] = labels
misc_df['misc_cluster'].value_counts()
# Out:
# /var/folders/zn/cnbb8tdj24g_h7k2_x0gxqwc0000gn/T/ipykernel_69691/3489489051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   misc_df['misc_cluster'] = labels
# misc_cluster
# 7    335364
# 2     35539
# 3     35164
# 8     31936
# 6     24809
# 1     24341
# 9     17858
# 4     17283
# 5     13149
# 0     12817
# Name: count, dtype: int64

# %%
# Mapping clusters to main topics
cluster_to_main_topic = {
    0: "Pests / Diseases / Soil",
    1: "Pests / Diseases / Soil",
    2: "Planting / Crops",
    3: "Planting / Crops",  
    4: "Misc / Other",
    5: "Planting / Crops",
    6: "Pests / Diseases / Soil",
    7: "Livestock / Animal Husbandry",
    8: "Pests / Diseases / Soil",
    9: "Livestock / Animal Husbandry"
}

misc_df['main_topic'] = misc_df['misc_cluster'].map(cluster_to_main_topic)

# Optional: handle mixed Cluster 3
misc_df.loc[misc_df['misc_cluster']==3, 'main_topic'] = \
    misc_df['cleaned_text'].apply(lambda x: 'Livestock / Animal husbandry' if 'pig' in x or 'pigs' in x else 'Planting / Crops')
# Out:
# /var/folders/zn/cnbb8tdj24g_h7k2_x0gxqwc0000gn/T/ipykernel_69691/1744745563.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   misc_df['main_topic'] = misc_df['misc_cluster'].map(cluster_to_main_topic)

# %%
# Merge back to main dataframe
eng_qs.loc[eng_qs['question_type']=='Misc / Other','question_type'] = misc_df['main_topic'].values

# %%
eng_qs['question_sent'] = pd.to_datetime(eng_qs['question_sent'], infer_datetime_format=True, format = 'mixed')
# Out:
# /var/folders/zn/cnbb8tdj24g_h7k2_x0gxqwc0000gn/T/ipykernel_69691/2557344351.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   eng_qs['question_sent'] = pd.to_datetime(eng_qs['question_sent'], infer_datetime_format=True, format = 'mixed')
# /var/folders/zn/cnbb8tdj24g_h7k2_x0gxqwc0000gn/T/ipykernel_69691/2557344351.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eng_qs['question_sent'] = pd.to_datetime(eng_qs['question_sent'], infer_datetime_format=True, format = 'mixed')

# %%
eng_qs['month'] = eng_qs['question_sent'].dt.month
eng_qs['year'] = eng_qs['question_sent'].dt.year

def uganda_season(m):
    if m in [3,4,5]:
        return "Season A Planting (March-May)"
    elif m in [6, 7,8]:
        return "Season A Harvesting (June-August)"
    elif m in [9,10,11]:
        return "Season B Planting (September-November)"
    else:
        return "Season B Harvesting (December-February)"

eng_qs['season'] = eng_qs['month'].apply(uganda_season)
# Out:
# /var/folders/zn/cnbb8tdj24g_h7k2_x0gxqwc0000gn/T/ipykernel_69691/2353776506.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eng_qs['month'] = eng_qs['question_sent'].dt.month
# /var/folders/zn/cnbb8tdj24g_h7k2_x0gxqwc0000gn/T/ipykernel_69691/2353776506.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eng_qs['year'] = eng_qs['question_sent'].dt.year
# /var/folders/zn/cnbb8tdj24g_h7k2_x0gxqwc0000gn/T/ipykernel_69691/2353776506.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eng_qs['season'] = eng_qs['month'].apply(uganda_season)

# %%
season_topic_counts = (
    eng_qs.groupby(['season','question_type'])
          .size()
          .reset_index(name='count')
        .sort_values(['count'], ascending=False)
        .head(20)
)

season_topic_counts.sort_values(['season','count'], ascending=[True, False], inplace=True)
season_topic_counts.head(10)
# Out:
#                                       season                 question_type  \
# 19         Season A Harvesting (June-August)  Livestock / Animal Husbandry
# 41         Season A Harvesting (June-August)              Planting / Crops
# 29         Season A Harvesting (June-August)       Pests / Diseases / Soil
# 25         Season A Harvesting (June-August)           Markets / Economics
# 28         Season A Harvesting (June-August)                  Misc / Other
# 89             Season A Planting (March-May)  Livestock / Animal Husbandry
# 110            Season A Planting (March-May)              Planting / Crops
# 98             Season A Planting (March-May)       Pests / Diseases / Soil
# 94             Season A Planting (March-May)           Markets / Economics
# 152  Season B Harvesting (December-February)  Livestock / Animal Husbandry
#
#       count
# 19   102848
# 41    58245
# 29    33742
# 25    16056
# 28     4152
# 89    85330
# 110   51995
# 98    29948
# 94    10756
# 152   86195

# %%
import seaborn as sns

plt.figure(figsize=(12,6))
ax = sns.barplot(data=season_topic_counts, x='season', y='count', hue='question_type', palette = 'gist_earth')
plt.xticks(rotation=5)
plt.ylabel("Number of Questions")
plt.title("Question Distribution by Season and Topic")
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
offset_x = 0.03  

for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(
            f'{int(height)}',
            (p.get_x() + p.get_width() / 2. + offset_x, height),  
            ha='center',
            va='bottom',
            fontsize=9
        )

plt.tight_layout()
plt.savefig('plot3.png')
plt.show()

# %%
topic_year_month = (
    eng_qs.groupby(['year','month','question_type'])
      .size()
      .reset_index(name='count')
)
top5 = (
    topic_year_month
        .groupby("question_type")["count"]
        .sum()
        .sort_values(ascending=False)
        .head(5)
        .index.tolist()
)

topic_year_month["z"] = (
    topic_year_month.groupby("question_type")["count"]
    .transform(lambda x: (x - x.mean()) / x.std(ddof=0))
)

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

axes = axes.flatten()

for i, topic in enumerate(top5):
    tm = topic_year_month[topic_year_month['question_type'] == topic]
    pivot = tm.pivot(index="month", columns="year", values="z").fillna(0)

    sns.heatmap(
        pivot,
        ax=axes[i],
        annot=True,
        fmt=".0f",
        cmap="crest"
    )
    axes[i].set_title(f"Topic: {topic}")

# Turn off the unused 6th subplot
axes[-1].axis("off")

plt.tight_layout()
plt.savefig('plot2.png')
plt.show()

# %%
crop_keywords = ['coffee', 'maize', 'beans', 'cassava', 'banana', 'tomato', 'crop', 'planting', 'harvest']
animal_keywords = ['pig', 'pigs', 'cattle', 'goat', 'goats', 'chicken', 'hens', 'poultry', 'livestock']

def correct_topic(row):
    text = row['cleaned_tokens']
    if row['question_type'] == 'Livestock / Animal Husbandry':
        if any(word in text for word in crop_keywords):
            return 'Planting / Crops'
    # if assigned to crops but mentions animals, fix
    elif row['question_type'] == 'Planting / Crops':
        if any(word in text for word in animal_keywords):
            return 'Livestock / Animal Husbandry'
    return row['question_type']

eng_qs['question_type'] = eng_qs.apply(correct_topic, axis=1)
# Out:
# /var/folders/zn/cnbb8tdj24g_h7k2_x0gxqwc0000gn/T/ipykernel_69691/136085131.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eng_qs['question_type'] = eng_qs.apply(correct_topic, axis=1)

# %%
eng_qs['question_type'].value_counts()
# Out:
# question_type
# Livestock / Animal Husbandry                                                                                         380376
# Planting / Crops                                                                                                     218782
# Pests / Diseases / Soil                                                                                              128915
# Markets / Economics                                                                                                   56737
# Misc / Other                                                                                                          17283
#                                                                                                                       ...
# Irrigation / Water; Markets / Economics; Technology / Equipment                                                           1
# Technology / Equipment; Policy / Finance                                                                                  1
# Planting / Crops; Harvest / Post-Harvest; Pests / Diseases / Soil; Livestock / Animal Husbandry; Policy / Finance         1
# Planting / Crops; Pests / Diseases / Soil; Irrigation / Water; Markets / Economics; Policy / Finance                      1
# Livestock / Animal Husbandry; Markets / Economics; Policy / Finance                                                       1
# Name: count, Length: 88, dtype: int64

# %%
topic_year_month["date"] = pd.to_datetime(
    topic_year_month["year"].astype(str) + "-" +
    topic_year_month["month"].astype(str).str.zfill(2)
)

# %%
colors = sns.color_palette("gist_earth", n_colors=len(top5))

plt.figure(figsize=(14, 6))

for i, topic in enumerate(top5):
    subset = topic_year_month[topic_year_month["question_type"] == topic]
    plt.plot(subset["date"], subset["z"], marker='o', label=topic, color = colors[i])

plt.axhline(0, color='black', linewidth=1, linestyle='--')
plt.title("Z-Score Trend of Top Topics Over Time")
plt.xlabel("Date")
plt.ylabel("Z-Score (Standardized Frequency)")
plt.legend(title="Topic")
plt.grid(True)

plt.tight_layout()
plt.savefig('f1.png')
plt.show()

# %%
# Before applying correction
before = eng_qs['question_type'].copy()

# Apply the correction
eng_qs['question_type'] = eng_qs.apply(correct_topic, axis=1)

# Compare
changed = (before != eng_qs['question_type']).sum()
print(f"Number of questions reassigned: {changed}")
# Out:
# Number of questions reassigned: 1527
# /var/folders/zn/cnbb8tdj24g_h7k2_x0gxqwc0000gn/T/ipykernel_69691/3645845638.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eng_qs['question_type'] = eng_qs.apply(correct_topic, axis=1)
